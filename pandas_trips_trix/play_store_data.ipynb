# %% [markdown]
# # import liberaries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# comment out these code if you eant to EDA automatically
# import ydata_profiling as yd
# profile = yd.ProfileReport(df)
# profile.to_file(output_file='../Output_ydata_profiling/ydata_profiling_googleplaystore.html')
# Out:
# ...
# Summarize dataset:  75%|███████▌  | 15/20 [00:04<00:00,  6.32it/s, Calculate auto correlation]                                                                                                                                                                                             c:\Users\Yahya\.conda\envs\ydata_profiling\lib\site-packages\scipy\stats\_stats_py.py:112: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   warnings.warn("The input array could not be properly "
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 113.68it/s]

# %% [markdown]
# # load the data from folder in to data fram

# %% [markdown]
# # lets on the look of data

# %%
df = pd.read_csv('../Data_sets/googleplaystore.csv')

# %%
df.head()
# Out:
#   App                                                                                                                                                                                                    \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook...
# 1  Coloring book moana                           ...
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3  Sketch - Draw & Paint                         ...
# 4  Pixel Draw - Number Art Coloring Book         ...
#
#    Category              Rating   Reviews    Size                 \
# 0  ART_AND_DESIGN        4.1            159  19M
# 1  ART_AND_DESIGN        3.9            967  14M
# 2  ART_AND_DESIGN        4.7          87510  8.7M
# 3  ART_AND_DESIGN        4.5         215644  25M
# 4  ART_AND_DESIGN        4.3            967  2.8M
#
#   Installs           Type   Price      Content Rating    \
# 0   10,000+          Free   0          Everyone
# 1   500,000+         Free   0          Everyone
# ...

# %% [markdown]
# # To check how many rowas and columns are there in the data set

# %%
df.shape
# Out:
# (10841, 13)

# %% [markdown]
# ## To check how many colums are null in the dataset

# %%
df.isnull().sum()
# Out:
# App                                                                                                                                                                                                      0
# Category                                                                                                                                                                                                 0
# Rating                                                                                                                                                                                                   0
# Reviews                                                                                                                                                                                                  0
# ...

# %%
# To check the percentage of null values
df.isnull().sum()/len(df)*100
# Out:
# App                                                                                                                                                                                                      0.000000
# Category                                                                                                                                                                                                 0.000000
# Rating                                                                                                                                                                                                   0.000000
# Reviews                                                                                                                                                                                                  0.000000
# ...

# %%
df.describe()
# Out:
#           Reviews
# count  1.084100e+04
# mean   4.441119e+05
# std    2.927629e+06
# min    0.000000e+00
# 25%    3.800000e+01
# 50%    2.094000e+03
# 75%    5.476800e+04
# max    7.815831e+07

# %%
df.sample(10) # Take sample from big dataset,
# Out:
#       App                                                                                                                                                                                                    \
# 8065   CX-42                                         ...
# 5636   One Night at Golden Freddy's                  ...
# 2017   Jewels Crush- Match 3 Puzzle                  ...
# 10821  Poop FR                                       ...
# 2004   Score! Hero                                   ...
# 9832   Lettre et demande d'emploi                    ...
# 6529   Calendars (En, Bn, Ar)                        ...
# 10619  Hidden Object Florida Vacation Adventure Fun G...
# 10600  Restaurant Inspections - FL                   ...
# 915    Acorn TV: World-class TV from Britain and Beyo...
#
#        Category              Rating   Reviews    Size                 \
# 8065   FAMILY                NaN              0  32M
# 5636   GAME                  3.3           2717  4.0M
# ...

# %% [markdown]
# # Assigement:
# ## write down all numeric variables and make them numeric
# 1. size
# 2. install
# 3. price
# 4. rating
# 5.

# %%
### to do that lets have check a unique values
df['Size               '].value_counts()
# Out:
# Varies with device     1695
# 11M                     198
# 12M                     196
# 14M                     194
# 13M                     191
# 15M                     184
# 17M                     160
# 19M                     154
# 26M                     149
# 16M                     149
# 25M                     143
# 20M                     139
# 21M                     138
# 10M                     136
# 24M                     136
# 18M                     133
# 23M                     117
# 22M                     114
# 29M                     103
# 27M                      97
# 28M                      95
# 30M                      84
# 33M                      79
# 3.3M                     77
# 37M                      76
# 35M                      72
# 31M                      70
# 2.9M                     69
# 2.3M                     68
# 2.5M                     68
# 2.8M                     65
# 3.4M                     65
# 32M                      63
# ...

# %% [markdown]
# # Check how many kb in one Mb? and how to calculate
# 1. convert kb into m
# 2. then remove m from all number
# 3. handle varies with device

# %%
df['Size               '].isnull().sum()
# Out:
# 0

# %% [markdown]
# install

# %%
df['Installs         '].value_counts()
# Out:
# 1,000,000+           1579
# 10,000,000+          1252
# 100,000+             1169
# 10,000+              1054
# 1,000+                908
# 5,000,000+            752
# 100+                  719
# 500,000+              539
# 50,000+               479
# 5,000+                477
# 100,000,000+          409
# 10+                   386
# 500+                  330
# 50,000,000+           289
# 50+                   205
# 5+                     82
# 500,000,000+           72
# 1+                     67
# 1,000,000,000+         58
# 0+                     14
# 0                       1
# Name: Installs         , dtype: int64

# %%
# do it as numeric columns or group into different groups following to belling methods.

# %%
df['Price    '].value_counts()
# Out:
# 0            10041
# $0.99          148
# $2.99          129
# $1.99           73
# $4.99           72
# $3.99           63
# $1.49           46
# $5.99           30
# $2.49           26
# $9.99           21
# $6.99           13
# $399.99         12
# $14.99          11
# $4.49            9
# $29.99           7
# $24.99           7
# $3.49            7
# $7.99            7
# $5.49            6
# $19.99           6
# $11.99           5
# $6.49            5
# $12.99           5
# $8.99            5
# $10.00           3
# $16.99           3
# $1.00            3
# $2.00            3
# $13.99           2
# $8.49            2
# $17.99           2
# $1.70            2
# $3.95            2
# $79.99           2
# $7.49            2
# $9.00            2
# $10.99           2
# $39.99           2
# $33.99           2
# $1.96            1
# $19.40           1
# $4.80            1
# $3.28            1
# $4.59            1
# $15.46           1
# $3.04            1
# $4.29            1
# ...

# %% [markdown]
# Remoce $ Sign from all columns using pandas

# %%
df['Type '].value_counts()
# Out:
# Free     10040
# Paid       800
# NaN          1
# Name: Type , dtype: int64

# %%
df['Type '].isnull().sum()
# Out:
# 0

# %%
df['Size               '].value_counts()
# Out:
# Varies with device     1695
# 11M                     198
# 12M                     196
# 14M                     194
# 13M                     191
# 15M                     184
# 17M                     160
# 19M                     154
# 26M                     149
# 16M                     149
# 25M                     143
# 20M                     139
# 21M                     138
# 10M                     136
# 24M                     136
# 18M                     133
# 23M                     117
# 22M                     114
# 29M                     103
# 27M                      97
# 28M                      95
# 30M                      84
# 33M                      79
# 3.3M                     77
# 37M                      76
# 35M                      72
# 31M                      70
# 2.9M                     69
# 2.3M                     68
# 2.5M                     68
# 2.8M                     65
# 3.4M                     65
# 32M                      63
# ...

# %%
df['Size               '].unique()
# Out:
# array(['19M                ', '14M                ',
#        '8.7M               ', '25M                ',
#        '2.8M               ', '5.6M               ',
#        '29M                ', '33M                ',
#        '3.1M               ', '28M                ',
#        '12M                ', '20M                ',
#        '21M                ', '37M                ',
#        '2.7M               ', '5.5M               ',
#        '17M                ', '39M                ',
#        '31M                ', '4.2M               ',
#        '7.0M               ', '23M                ',
#        '6.0M               ', '6.1M               ',
#        '4.6M               ', '9.2M               ',
#        '5.2M               ', '11M                ',
#        '24M                ', 'Varies with device ',
#        '9.4M               ', '15M                ',
#        '10M                ', '1.2M               ',
#        '26M                ', '8.0M               ',
# ...

# %% [markdown]
# Task, we need to conver M to KB and remoce m from data points
